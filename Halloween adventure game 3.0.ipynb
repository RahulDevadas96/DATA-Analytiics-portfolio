# %%
# introductory docstring
"""
Its a halloween night and you need to visit
your neighbours and ask them for trick or treat,
Your parents have asked you to return home.
You have 3 houses to visit.

Trick or Treat? (Trick = yes, Treat = no)"""


# Function for play again / not

def start():
    # give some prompts.
    print(f"""
Its a halloween night and you need to visit
Your neighbours and ask them for trick or treat,
Your parents have asked you to return home.
You have 3 houses to visit.

You entered the 1st house - Vampires Theme. You walk inside to the main gate.
You saw a still women in a bat constume watching through the door,
Would you like to interact with the women or head to the door for candies.
(select 1 or 2)

1. ignore her and move to the main door
2. interact with the women in Vampire costume""")

    # Get input()
    interaction = input(prompt = "enter 1 or 2 -" )

    if interaction == "1":
        print(f"""
Thats a safe play now you move towards the door.You can now ring the bell.
When you rang the bell the women stood up wipes the blood on her mouth
& starts to move towards you. You ask Trick or treat?
She replies treat and shows you the basket of candies.
How many candies would you like to pick up?""")

        input(prompt ="enter a number -")
    
        print("Do you want to spend time in this house?")
        print("1. Get out with candies")
        print("2. Listen to spooky Vampires stories ")

        # take the contenders input
        house_question = input(prompt="enter 1 or 2")

        if "1" in house_question:
            # contender typed 1 take him to the Halloween School Bus Massacre theme
            bus_house()
        else:
            # else call game_over() Function with the "reason" argument
            game_over("You Journey ends here. Hope you survive the journey of life")

    else:
        print("The women transforms into a real vampire and kills you")
        game_over("You Journey ends here. Hope you survive the journey of life")


# 2 stage / house 2- Halloween School Bus Massacre theme
def bus_house():
    # some prompts
    print(f"""
You entered the 2nd house - Halloween School Bus Massacre theme. You open the Bus door,& entered the bus.
You saw a bus driver badly wounded,you asked Trick or treat,
He replied i will give you treat but can you show me any trick?
which trick you want to show to him?
1. Vanishing Trick - tell him to close the eyes and run away
2. spray- snowspray and run
""")

    # Intake()
    trick = input(prompt="enter 1 or 2")

    if trick == "1":
        # He heads to the Goblin house
        print("\n Thats really smart of you to escape from the place, as th guy was looking really creepy")
        goblin_house()
    elif trick == "2":
        # Contender is dead, game_over() - "Logic"
        game_over("He got angry , hits you with a axe and kills you, Game over.")
    else:
        # game_over() - "Logic"
        game_over("You should have stayed away from psychos.")


# 3 stage / house 3- Goblin house
def goblin_house():
    # give some prompts
    print(f"""
You entered the 3rd house - Goblins house, The door was really slimy tried
to know it with your stick,
You saw a bus driver badly wounded,
you asked Trick or Treat, he replied he wants to see some tricks?
which trick you want to show to him?
What is the right answer?
1.Snow spray
2.Break the Pumpkin
3.Cream pie smash on face """)

    import random

    # Declaring items
    number = random.randint(1,3)  # random number - same for each guess

    # looping till the contender guess right
    while True:
        item = input(prompt='\n What is your guess (1,2,3)?\n> ')

        # converting choice for numerical comparison
        try:
            item = int(item)
            if item == number:
                print("You are going home!")
                break;

            # setting a different error message for inner and outer loops
            else:
                print("Slimy things fell on you")
        except:
            print("can you put any number ?")
        # conditional statement based on user input

    print(f"""
      You have got a lot of candies today, now its time to go home "
          Hope you had great fun in this years halloween"
           Wish you a

██╗  ██╗ █████╗ ██████╗ ██████╗ ██╗   ██╗    ██╗  ██╗ █████╗ ██╗     ██╗      ██████╗ ██╗    ██╗███████╗███████╗███╗   ██╗
██║  ██║██╔══██╗██╔══██╗██╔══██╗╚██╗ ██╔╝    ██║  ██║██╔══██╗██║     ██║     ██╔═══██╗██║    ██║██╔════╝██╔════╝████╗  ██║
███████║███████║██████╔╝██████╔╝ ╚████╔╝     ███████║███████║██║     ██║     ██║   ██║██║ █╗ ██║█████╗  █████╗  ██╔██╗ ██║
██╔══██║██╔══██║██╔═══╝ ██╔═══╝   ╚██╔╝      ██╔══██║██╔══██║██║     ██║     ██║   ██║██║███╗██║██╔══╝  ██╔══╝  ██║╚██╗██║
██║  ██║██║  ██║██║     ██║        ██║       ██║  ██║██║  ██║███████╗███████╗╚██████╔╝╚███╔███╔╝███████╗███████╗██║ ╚████║
╚═╝  ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝        ╚═╝       ╚═╝  ╚═╝╚═╝  ╚═╝╚══════╝╚══════╝ ╚═════╝  ╚══╝╚══╝ ╚══════╝╚══════╝╚═╝  ╚═══╝


""")


# game_over Function{fail()function} = the "Logic"
def game_over(Logic):
    # print the "Logic" in a new line (\n)
    print("\n" + Logic)
    print("GAME OVER!")
    # Ask the COntender to Play again or not by activating Play_again() Function
    play_again()

  
def play_again():
    print("\nplay Trick or Treat again ? (yes= Treat or no= Trick)")

    # convert the player's input to lower_case
    answer = input(prompt ='')
    answer = answer.lower()

    if "treat" in answer:
        # # contender typed "Treat" or "yes" begin
        start()
    else:
        # contender types anything other than "Treat", exit() the journey
        exit()


def begin():
    print(intro._doc_)

    answer = input().lower()

    if "Treat" in answer:
        # contender typed "Treat" begin
        start()
    else:
        # contender types anything other than "Treat", exit() the journey
        exit()

    #  1 stage/house 1- Vampires Theme


# start the game
start()
# Out:
# Its a halloween night and you need to visit
# your neighbours and ask them for trick or treat,
# Your parents have asked you to return home.
# You have 3 houses to visit.
#
# You entered the 1st house - Vampires Theme. You walk inside to the main gate.
# You saw a still women in a bat constume watching through the door,
# would you like to interact with the women or head to the door for candies.
# (select 1 or 2)
#
# 1. ignore her and move to the main door
# 2. interact with the women in Vampire costume
# enter 1 or 2 -1
#
# Thats a safe play now you move towards the door.You can now ring the bell.
# When you rang the bell the women stood up wipes the blood on her mouth
# & starts to move towards you. You ask Trick or treat?
# She replies treat and shows you the basket of candies.
# How many candies would you like to pick up?
# enter a number -23
# Do you want to spend time in this house?
# 1. Get out with candies
# 2. Listen to spooky Vampires stories
# enter 1 or 21
#
# ...
